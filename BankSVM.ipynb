# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#reading data, coverting all '?' to Nan 
dfBank = pd.read_csv('Bank-full.csv',sep=';',na_values=['nan','unknown'])
#reading data, coverting all '?' to Nan

# %%
dfBank.dropna(inplace = True)
dfBank.head(2)
dfBank.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
dfBank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7842 entries, 24060 to 45210
# Data columns (total 17 columns):
# age          7842 non-null int64
# job          7842 non-null object
# marital      7842 non-null object
# education    7842 non-null object
# default      7842 non-null object
# balance      7842 non-null int64
# housing      7842 non-null object
# loan         7842 non-null object
# contact      7842 non-null object
# day          7842 non-null int64
# month        7842 non-null object
# duration     7842 non-null int64
# campaign     7842 non-null int64
# pdays        7842 non-null int64
# previous     7842 non-null int64
# poutcome     7842 non-null object
# y            7842 non-null object
# dtypes: int64(7), object(10)
# memory usage: 1.1+ MB

# %%
dfBank.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  7842.000000   7842.000000  7842.000000  7842.000000  7842.000000
# mean     40.783856   1552.343280    14.260010   261.290615     2.064269
# std      11.282964   3084.580003     7.885328   236.203272     1.566109
# min      18.000000  -1884.000000     1.000000     5.000000     1.000000
# 25%      32.000000    162.000000     7.000000   113.000000     1.000000
# 50%      38.000000    595.000000    14.000000   194.000000     2.000000
# 75%      47.000000   1733.750000    20.000000   324.000000     2.000000
# max      89.000000  81204.000000    31.000000  2219.000000    16.000000
#
#              pdays     previous
# count  7842.000000  7842.000000
# mean    223.252869     3.184264
# std     111.830127     4.614190
# min       1.000000     1.000000
# 25%     133.000000     1.000000
# 50%     195.000000     2.000000
# 75%     326.000000     4.000000
# max     871.000000   275.000000

# %%
dfBank.shape
# Out:
# (7842, 17)

# %%
#plotting histogram for each column

from matplotlib.pyplot import figure
import matplotlib.gridspec as gridspec
# Plot figure with subplots of different sizes
fig = plt.figure(1)
# set up subplot grid
gridspec.GridSpec(4,4)
# large subplot
dfBank.iloc[:,11:17].hist()
plt.show()
# large subplot
dfBank.iloc[:,:11].hist()
plt.show()

# %%
# %matplotlib inline
import seaborn as sns
contact_count = dfBank['contact'].value_counts()
sns.set(style="darkgrid")
sns.barplot(contact_count.index, contact_count.values, alpha=0.9)
plt.title('Frequency Distribution of Contacts')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Contacts', fontsize=12)
plt.show()

contact_count = dfBank['job'].value_counts()
sns.set(style="darkgrid")
sns.barplot(contact_count.index, contact_count.values, alpha=0.9)
plt.title('Frequency Distribution of Job')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xticks(rotation=60)
plt.xlabel('job', fontsize=12)
plt.show()

contact_count = dfBank['marital'].value_counts()
sns.set(style="darkgrid")
sns.barplot(contact_count.index, contact_count.values, alpha=0.9)
plt.title('Frequency Distribution of marital')
plt.ylabel('Number of Occurrences', fontsize=12)
# plt.xticks(rotation=60)
plt.xlabel('marital', fontsize=12)
plt.show()
contact_count = dfBank['education'].value_counts()
sns.set(style="darkgrid")
sns.barplot(contact_count.index, contact_count.values, alpha=0.9)
plt.title('Frequency Distribution of education')
plt.ylabel('Number of Occurrences', fontsize=12)
# plt.xticks(rotation=60)
plt.xlabel('education', fontsize=12)
plt.show()

contact_count = dfBank['default'].value_counts()
sns.set(style="darkgrid")
sns.barplot(contact_count.index, contact_count.values, alpha=0.9)
plt.title('Frequency Distribution of default')
plt.ylabel('Number of Occurrences', fontsize=12)
# plt.xticks(rotation=60)
plt.xlabel('default', fontsize=12)
plt.show()

contact_count = dfBank['housing'].value_counts()
sns.set(style="darkgrid")
sns.barplot(contact_count.index, contact_count.values, alpha=0.9)
plt.title('Frequency Distribution of housing')
plt.ylabel('Number of Occurrences', fontsize=12)
# plt.xticks(rotation=60)
plt.xlabel('housing', fontsize=12)
plt.show()

contact_count = dfBank['loan'].value_counts()
sns.set(style="darkgrid")
sns.barplot(contact_count.index, contact_count.values, alpha=0.9)
plt.title('Frequency Distribution of loan')
plt.ylabel('Number of Occurrences', fontsize=12)
# plt.xticks(rotation=60)
plt.xlabel('loan', fontsize=12)
plt.show()

# %%
# plt.figure(figsize = (10,10))
import matplotlib.gridspec as gridspec
# Plot figure with subplots of different sizes
fig = plt.figure(1)
# set up subplot grid
gridspec.GridSpec(4,4)
dfBank.iloc[:,0:11].plot(kind='density', subplots=True, layout=(2,2), sharex=False)
plt.show()
dfBank.iloc[:,11:13].plot(kind='density', subplots=True, layout=(2,2), sharex=False)
plt.show()
dfBank.iloc[:,13:19].plot(kind='density', subplots=True, layout=(2,2), sharex=False)
plt.show()
# dfBank.iloc[:,17:19].plot(kind='density', subplots=True, layout=(2,2), sharex=False)
# plt.show()

# %%
#Encode the categorical data
for col in dfBank.columns:
    if dfBank[col].dtype==object:
           dfBank[col]=dfBank[col].astype('category')
           dfBank[col]=dfBank[col].cat.codes
dfBank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7842 entries, 24060 to 45210
# Data columns (total 17 columns):
# age          7842 non-null int64
# job          7842 non-null int8
# marital      7842 non-null int8
# education    7842 non-null int8
# default      7842 non-null int8
# balance      7842 non-null int64
# housing      7842 non-null int8
# loan         7842 non-null int8
# contact      7842 non-null int8
# day          7842 non-null int64
# month        7842 non-null int8
# duration     7842 non-null int64
# campaign     7842 non-null int64
# pdays        7842 non-null int64
# previous     7842 non-null int64
# poutcome     7842 non-null int8
# y            7842 non-null int8
# dtypes: int64(7), int8(10)
# memory usage: 566.7 KB

# %%
#correlation in data
corr = dfBank.corr()
import seaborn as sns
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
dfBank.shape
msk = np.random.rand(len(dfBank)) < 0.01
DATA = dfBank[msk]
# test = df[~msk]
DATA.shape
#45211 records and 16 features 1 class label column
# Out:
# (74, 17)

# %%
#dividing the data into attributes and labels
X = DATA.drop('y', axis=1) 
y = DATA['y']

# %%
#spliting in train and test set
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
#Linear
from sklearn.svm import SVC  
svclassifier = SVC(kernel='linear')  
svclassifier.fit(X_train, y_train) 
y_pred = svclassifier.predict(X_test)

# %%
y_pred = svclassifier.predict(X_test)

# %%
#Evaluating the algorithm
from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(y_test,y_pred))  
print(classification_report(y_test,y_pred))
# Out:
# [[13  2]
#  [ 3  2]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84        15
#            1       0.50      0.40      0.44         5
#
#    micro avg       0.75      0.75      0.75        20
#    macro avg       0.66      0.63      0.64        20
# weighted avg       0.73      0.75      0.74        20

# %%
#ACCURACY
from sklearn import metrics
# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.75

# %%
#Polynomial Kernel

# %%
#Polynomial Kernel
from sklearn.svm import SVC  
svclassifier = SVC(kernel='poly', degree=2)  
svclassifier.fit(X_train, y_train)
# Out:
# C:\Users\SaniaZafar\PycharmProjects\MLWork\venv\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=2, gamma='auto_deprecated',
#   kernel='poly', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = svclassifier.predict(X_test)

# %%
#Evaluating the algorithm
from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(y_test,y_pred))  
print(classification_report(y_test,y_pred))

# %%
#ACCURACY
# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %%
#Gaussian
from sklearn.svm import SVC  
svclassifier = SVC(kernel='rbf')  
svclassifier.fit(X_train, y_train)
# Out:
# C:\Users\SaniaZafar\PycharmProjects\MLWork\venv\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = svclassifier.predict(X_test)

# %%
#Evaluating the algorithm
from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(y_test,y_pred))  
print(classification_report(y_test,y_pred))
# Out:
# [[15  0]
#  [ 5  0]]
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86        15
#            1       0.00      0.00      0.00         5
#
#    micro avg       0.75      0.75      0.75        20
#    macro avg       0.38      0.50      0.43        20
# weighted avg       0.56      0.75      0.64        20
# C:\Users\SaniaZafar\PycharmProjects\MLWork\venv\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#ACCURACY
# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.75

# %%
from sklearn.svm import SVC  
svclassifier = SVC(kernel='sigmoid')  
svclassifier.fit(X_train, y_train)
# Out:
# C:\Users\SaniaZafar\PycharmProjects\MLWork\venv\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='sigmoid', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = svclassifier.predict(X_test)

# %%
#Evaluating the algorithm
from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(y_test,y_pred))  
print(classification_report(y_test,y_pred))
# Out:
# [[9 5]
#  [1 0]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.64      0.75        14
#            1       0.00      0.00      0.00         1
#
#    micro avg       0.60      0.60      0.60        15
#    macro avg       0.45      0.32      0.38        15
# weighted avg       0.84      0.60      0.70        15

# %%
#ACCURACY
# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6

# %%
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets


def make_meshgrid(x, y, h=.02):
    """Create a mesh of points to plot in

    Parameters
    ----------
    x: data to base x-axis meshgrid on
    y: data to base y-axis meshgrid on
    h: stepsize for meshgrid, optional

    Returns
    -------
    xx, yy : ndarray
    """
    x_min, x_max = x.min() - 1, x.max() + 1
    y_min, y_max = y.min() - 1, y.max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    return xx, yy


def plot_contours(ax, clf, xx, yy, **params):
    """Plot the decision boundaries for a classifier.

    Parameters
    ----------
    ax: matplotlib axes object
    clf: a classifier
    xx: meshgrid ndarray
    yy: meshgrid ndarray
    params: dictionary of params to pass to contourf, optional
    """
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    out = ax.contourf(xx, yy, Z, **params)
    return out


# import some data to play with

# Take the first two features. We could avoid this by using a two-dim dataset 
X =DATA.iloc[:,12:14]
# we create an instance of SVM and fit out data. We do not scale our
# data since we want to plot the support vectors
C = 1.0  # SVM regularization parameter
models = (svm.SVC(kernel='linear', C=C),
          svm.LinearSVC(C=C),
          svm.SVC(kernel='rbf', gamma=0.7, C=C),
          svm.SVC(kernel='poly', degree=3, C=C))
models = (clf.fit(X, y) for clf in models)

# title for the plots
titles = ('SVC with linear kernel',
          'LinearSVC (linear kernel)',
          'SVC with RBF kernel',
          'SVC with polynomial (degree 3) kernel')

# Set-up 2x2 grid for plotting.
fig, sub = plt.subplots(2, 2)
plt.subplots_adjust(wspace=0.4, hspace=0.4)

X0, X1 = X.iloc[:, 0], X.iloc[:, 1]
xx, yy = make_meshgrid(X0, X1)

for clf, title, ax in zip(models, titles, sub.flatten()):
    plot_contours(ax, clf, xx, yy,
                  cmap=plt.cm.coolwarm, alpha=0.8)
    ax.scatter(X0, X1, c=y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xlabel('Duration')
    ax.set_ylabel('Campaign')
    ax.set_xticks(())
    ax.set_yticks(())
    ax.set_title(title)

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# C:\Users\SaniaZafar\PycharmProjects\MLWork\venv\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\SaniaZafar\PycharmProjects\MLWork\venv\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
